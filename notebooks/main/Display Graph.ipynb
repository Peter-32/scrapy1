# %%
import re
import nltk
import roughviz
import pandas as pd
from nltk.tokenize import word_tokenize

# Clean text
with open('../../data/processed/text.txt', 'r') as file:
    text = file.read()
with open('../../data/raw/programming_languages_list.txt', 'r') as file:
    programming_languages = file.read().split("\n")
text = text.replace("You have JavaScript disabled on your browser. You will not be able to apply for this position without enabling javascript. If you need assistance with enabling javascript, please click here for assistance.","")
text = text.replace("\nData Networking\n", "\n\n")
text = text.replace("\nData Science\n", "\n\n")
text = text.replace("Java Script", "JavaScript")
text = text.replace("C#", "csharp")
wnl = nltk.WordNetLemmatizer()
words = word_tokenize(text)
words = [re.sub(r'[^A-Za-z_\s\-!+*#]', '', w).lower() for w in words]
words = [wnl.lemmatize(w) for w in words if w.strip() != '']
words = ["c#" if x == "csharp" else x for x in words]

# Count words
fd = nltk.FreqDist(words)
with open('../../data/processed/word_count.txt', 'w') as file:
    file.write("\n".join([str((x,y)) for (x,y) in fd.most_common(100000) if x in programming_languages]))

# Display Graph (Jupyter Notebook only)
common_words = [(x,y) for (x,y) in fd.most_common(100000) if x in programming_languages]
df = pd.DataFrame()
df["word"] = [x for (x,y) in common_words]
df["count"] = [y for (x,y) in common_words]
roughviz.barh(df["word"].iloc[0:20], df["count"].iloc[0:20])
# Out:
# <html>
# <body>
#
# <div id="ywawuiqsga"></div>
#
# <script src="https://requirejs.org/docs/release/2.3.6/minified/require.js"></script>
# <script>
# require.config({paths: {roughViz: "https://unpkg.com/rough-viz@1.0.5/dist/roughviz.min"}});
# require(["roughViz"], function(roughViz) {
#
# new roughViz.BarH(
#   {
#     element: "#".concat("ywawuiqsga"),
#     data: {
#       labels: ['java', 'database', 'sql', 'oracle', 'c', 'python', 'aws', 'perl', 'javascript', 'ansible', 'c++', 'r', 'scala', 'matlab', 'puppet', 'chef', 'php', 'mysql', 'apex', 'nosql'],
#       values: [70, 69, 59, 53, 36, 35, 28, 17, 16, 15, 13, 13, 12, 10, 10, 10, 10, 10, 7, 6]
#     },
# 	axisFontSize: "1.5rem",
# 	axisRoughness: 0.5,
# 	axisStrokeWidth: 0.5,
# 	bowing: 0,
# 	color: "skyblue",
# 	fillStyle: "cross-hatch",
# 	fillWeight: 0,
# 	font: 0,
# 	highlight: "green",
# 	innerStrokeWidth: 0,
# 	labelFontSize: "2rem",
# 	padding: 0.1,
# 	roughness: 1,
# 	simplification: 0.2,
# 	stroke: "black",
# 	strokeWidth: 1,
# 	title: "",
# 	titleFontSize: "3rem",
# 	tooltipFontSize: "3rem",
# 	xLabel: "",
# 	yLabel: "",
# 	height: 400,
# 	width: 700,
# 	interactive: true
#   }
# );
# 	var text = document.querySelectorAll(".xAxisywawuiqsga .tick text");
# 	var i;
# 	for (i = 0; i < text.length; i++) {
# 		text[i].setAttribute("transform", "rotate(0)");
# 		text[i].style.textAnchor="middle";
# 	}
# 	document.getElementById("ywawuiqsga").style.height = "380px";
# 	document.querySelector("#ywawuiqsga svg").style.height = "380px";
# });
# </script>
#
# </body>
# </html>

# %%
roughviz.barh(df["word"].iloc[20:40], df["count"].iloc[20:40])
# Out:
# <html>
# <body>
#
# <div id="ppyzwjlsjc"></div>
#
# <script src="https://requirejs.org/docs/release/2.3.6/minified/require.js"></script>
# <script>
# require.config({paths: {roughViz: "https://unpkg.com/rough-viz@1.0.5/dist/roughviz.min"}});
# require(["roughViz"], function(roughViz) {
#
# new roughViz.BarH(
#   {
#     element: "#".concat("ppyzwjlsjc"),
#     data: {
#       labels: ['azure', 'powershell', 'clojure', 'ruby', 'nlp', 'c#', 'cecil', 'bash', 'vhdl', 'fabric', 'pearl', 'postgresql', 'prolog', 'xsb', 'haskell', 'cassandra', 'mongodb', 'kafka', 'spark', 'simulink'],
#       values: [6, 6, 6, 5, 4, 4, 4, 4, 3, 3, 3, 3, 3, 3, 3, 2, 2, 2, 2, 2]
#     },
# 	axisFontSize: "1.5rem",
# 	axisRoughness: 0.5,
# 	axisStrokeWidth: 0.5,
# 	bowing: 0,
# 	color: "skyblue",
# 	fillStyle: "cross-hatch",
# 	fillWeight: 0,
# 	font: 0,
# 	highlight: "green",
# 	innerStrokeWidth: 0,
# 	labelFontSize: "2rem",
# 	padding: 0.1,
# 	roughness: 1,
# 	simplification: 0.2,
# 	stroke: "black",
# 	strokeWidth: 1,
# 	title: "",
# 	titleFontSize: "3rem",
# 	tooltipFontSize: "3rem",
# 	xLabel: "",
# 	yLabel: "",
# 	height: 400,
# 	width: 700,
# 	interactive: true
#   }
# );
# 	var text = document.querySelectorAll(".xAxisppyzwjlsjc .tick text");
# 	var i;
# 	for (i = 0; i < text.length; i++) {
# 		text[i].setAttribute("transform", "rotate(0)");
# 		text[i].style.textAnchor="middle";
# 	}
# 	document.getElementById("ppyzwjlsjc").style.height = "380px";
# 	document.querySelector("#ppyzwjlsjc svg").style.height = "380px";
# });
# </script>
#
# </body>
# </html>
